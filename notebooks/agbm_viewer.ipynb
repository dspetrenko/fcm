# %% [markdown]
# ### import

# %%
import os
from pathlib import Path
_src_path = Path(os.getcwd()).parent / 'src' 

import sys 

if _src_path.as_posix() not in sys.path: 
    sys.path.append(_src_path.as_posix())
    sys.path.append(_src_path.parent.as_posix())

from agbmfc.charts import plot_target_and_pred
from agbmfc.loading import read_image_tensor
# Out:
# C:\Users\Denis\.conda\envs\hsem\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\Denis\.conda\envs\hsem\lib\site-packages\numpy\.libs\libopenblas.EL2C6PLE4ZYW3ECEVIV3OXXGRN2NRFM2.gfortran-win_amd64.dll
# C:\Users\Denis\.conda\envs\hsem\lib\site-packages\numpy\.libs\libopenblas.PYQHXLVVQ7VESDPUVUADXEVJOBGHJPAY.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %% [markdown]
# ### view

# %%
pred_agbm = read_image_tensor(fr'../response.tif', precision=16).reshape(256, 256)
target_agbm = read_image_tensor(fr'../data_sample/fed6bb57_agbm.tif', precision=16).reshape(256, 256)
plot_target_and_pred(target_agbm, pred_agbm)
